# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.preprocessing import MinMaxScaler, StandardScaler
sys.path.append('/users/mtaranov/genome3D/')
from models_3d import Genome3D_DNN_FC
from utils import normalize_features_sampl_by_f, concat_motifs, get_features, get_labels, subsample_data, normalize_features, reconstruct_2d, printMatrix, binarize, zscore, get_2D, plot_prediction, change_scale
#from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 1: GeForce GTX TITAN X (CNMeM is disabled, cuDNN 5005)

# %%
contacts='pe'
path='/users/mtaranov/datasets_3d/by_chr_dist_matched_'+contacts+'/'
day='d0'
thres='10'

X_train = np.load(path+'motifs/'+day+'_thres_'+thres+'_train_'+contacts+'_out_btw_nodes_3_0.0001/mat.npy')
X_test = np.load(path+'motifs/'+day+'_thres_'+thres+'_test_'+contacts+'_out_btw_nodes_3_0.0001/mat.npy')
X_valid = np.load(path+'motifs/'+day+'_thres_'+thres+'_valid_'+contacts+'_out_btw_nodes_3_0.0001/mat.npy')

y_train = get_labels(path+day+'_y_train_thres_'+thres+'.npy')
y_test = get_labels(path+day+'_y_test_thres_'+thres+'.npy')
y_valid = get_labels(path+day+'_y_valid_thres_'+thres+'.npy')

# %%
X_train_normalized, X_valid_normalized, X_test_normalized = normalize_features_sampl_by_f(X_train, X_valid, X_test)

# %%
dnn_normalized = Genome3D_DNN_FC(num_features=1920, use_deep_CNN=False)
validation_data = (X_valid_normalized, y_valid)
dnn_normalized.train(X_train_normalized, y_train, validation_data)
# Out:
# Training model...

# %%
print(dnn_normalized.test(X_test_normalized, y_test))
print(dnn_normalized.test(X_train_normalized, y_train))
print(dnn_normalized.test(X_valid_normalized, y_valid))

# %%
#save model and weights
dnn_normalized.save(contacts+'_dnn_FC_Window_motifs', '/users/mtaranov/LongRange3D/')

# %% [markdown]
# # DeepLift

# %%
weights='/users/mtaranov/LongRange3D/weights/'+contacts+'_dnn_FC_Window_motifs.weights.h5'
json_model='/users/mtaranov/LongRange3D/models/'+contacts+'_dnn_FC_Window_motifs.arch.json'

# %%
scores = dnn_normalized.deeplift(X_valid_normalized[np.where(y_valid ==1)[0]], weights, json_model, batch_size=128)
# Out:
# True
# nonlinear_mxts_mode is set to: RevealCancel

# %%
np.save('/users/mtaranov/LongRange3D/deeplift_scores/'+contacts+'_scores_dnn_FC_Window_motifs.npy', scores)

# %%
scores.shape
# Out:
# (898, 1920)

# %%
plt.plot(np.mean(scores[10:,:], axis=0))

# %%
plt.pcolor(scores[10:,:], cmap='hot', vmin=np.min(scores[10:,:]), vmax=np.max(scores[10:,:])) # cmap='RdBu'
plt.xlabel('motifs/features')
plt.ylabel('examples')
plt.title('DeepLift Score - Window Motifs')
plt.colorbar()

# %%
motif_names=np.loadtxt('/users/mtaranov/datasets_3d/dist_matched_PE/motifs/train_PE_out_btw_nodes_3_0.0001/motif_names.txt', dtype=str, delimiter='/')[:,6:].reshape(640,)
top_3_hits_names=[]
for i in motif_names:
    for j in range(3):
        top_3_hits_names.append(i)
top_3_hits_names = np.array(top_3_hits_names)

# %%
score_per_feature=np.mean(scores, axis=0)

# %%
DeepLift_Window_Motifs=top_3_hits_names[score_per_feature.argsort()[::-1]]

# %%
np.where(DeepLift_Window_Motifs=='CTCF_HUMAN')
# Out:
# (array([ 103,  656, 1143]),)

# %%
DeepLift_Window_Motifs.shape
# Out:
# (1920,)

# %%
DeepLift_Window_Motifs[:100]
# Out:
# array(['HXB6_HUMAN', 'ELF3_HUMAN', 'ZN589_HUMAN', 'HXB6_HUMAN',
#        'BRAC_HUMAN', 'ELF3_HUMAN', 'PIT1_HUMAN', 'EOMES_HUMAN',
#        'GATA6_HUMAN', 'ZEP2_HUMAN', 'SRBP2_HUMAN', 'THB_HUMAN',
#        'RHXF1_HUMAN', 'ZN410_HUMAN', 'HXD13_HUMAN', 'TFAP4_HUMAN',
#        'HXB6_HUMAN', 'DLX6_HUMAN', 'ZBTB4_HUMAN', 'ZBT18_HUMAN',
#        'ELF3_HUMAN', 'SOX15_HUMAN', 'FOXJ2_HUMAN', 'ANDR_HUMAN',
#        'GCM2_HUMAN', 'HXA5_HUMAN', 'MGAP_HUMAN', 'NR1I2_HUMAN',
#        'NR6A1_HUMAN', 'NR5A2_HUMAN', 'HME2_HUMAN', 'FOXJ2_HUMAN',
#        'SOX4_HUMAN', 'ZBT18_HUMAN', 'MLXPL_HUMAN', 'THB_HUMAN',
#        'HIF1A_HUMAN', 'PAX4_HUMAN', 'TYY1_HUMAN', 'OTX1_HUMAN',
#        'PO3F2_HUMAN', 'ESR2_HUMAN', 'ISX_HUMAN', 'HLTF_HUMAN', 'HLF_HUMAN',
#        'CREM_HUMAN', 'E4F1_HUMAN', 'HLTF_HUMAN', 'PAX1_HUMAN',
#        'SOX10_HUMAN', 'ARX_HUMAN', 'HXD4_HUMAN', 'TGIF2_HUMAN',
#        'PO3F4_HUMAN', 'HXB1_HUMAN', 'PAX2_HUMAN', 'KLF13_HUMAN',
#        'GFI1_HUMAN', 'ESR1_HUMAN', 'CENPB_HUMAN', 'AP2D_HUMAN',
#        'SOX21_HUMAN', 'CDX1_HUMAN', 'PAX4_HUMAN', 'SMAD4_HUMAN',
#        'SOX17_HUMAN', 'HMX2_HUMAN', 'GABP1_HUMAN', 'BRAC_HUMAN',
#        'SOX15_HUMAN', 'GATA6_HUMAN', 'MAFB_HUMAN', 'SRF_HUMAN',
#        'LMX1A_HUMAN', 'TFAP4_HUMAN', 'HES1_HUMAN', 'CR3L2_HUMAN',
#        'SCRT2_HUMAN', 'TF65_HUMAN', 'TBX20_HUMAN', 'RUNX3_HUMAN',
#        'RFX5_HUMAN', 'FOXJ3_HUMAN', 'HXC6_HUMAN', 'UBIP1_HUMAN',
#        'TBX3_HUMAN', 'SMAD3_HUMAN', 'LHX4_HUMAN', 'PPARG_HUMAN',
#        'GLI1_HUMAN', 'PBX2_HUMAN', 'HIF1A_HUMAN', 'MEIS2_HUMAN',
#        'FOXJ3_HUMAN', 'ZIC1_HUMAN', 'HME2_HUMAN', 'RFX5_HUMAN',
#        'HES1_HUMAN', 'CREB5_HUMAN', 'NFIA_HUMAN'],
#       dtype='|S11')
