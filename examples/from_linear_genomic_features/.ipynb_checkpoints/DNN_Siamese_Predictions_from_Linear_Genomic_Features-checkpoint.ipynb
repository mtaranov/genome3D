# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import copy
sys.path.append('/users/mtaranov/LongRange3D/')
from models_binnedFeat import LongRangeDNN
from utils import get_features, get_labels, subsample_data, normalize_features, reconstruct_2d, printMatrix, binarize, zscore, get_2D, plot_prediction, change_scale
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# INFO (theano.gof.compilelock): Waiting for existing lock by process '21814' (I am process '21799')
# INFO (theano.gof.compilelock): To manually release the lock, delete /users/mtaranov/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/lock_dir
# Using gpu device 1: GeForce GTX TITAN X (CNMeM is disabled, cuDNN None)

# %%
contacts='pe'
path='/users/mtaranov/datasets_3d/by_chr_dist_matched_'+contacts+'/'
X_train = get_features(path+'d0_X_train_thres_10.npy')
y_train = get_labels(path+'d0_y_train_thres_10.npy')
X_valid = get_features(path+'d0_X_valid_thres_10.npy')
y_valid = get_labels(path+'d0_y_valid_thres_10.npy')
X_test = get_features(path+'d0_X_test_thres_10.npy')
y_test = get_labels(path+'d0_y_test_thres_10.npy')

# %%
X_train_normalized, X_valid_normalized, X_test_normalized = normalize_features(X_train, X_valid, X_test)

# %%
X_train_normalized.shape, X_valid_normalized.shape, X_test_normalized.shape
# Out:
# ((6710, 1, 10, 2), (1796, 1, 10, 2), (988, 1, 10, 2))

# %% [markdown]
# # without distance

# %%
dnn_normalized = LongRangeDNN(num_features=9, use_deep_CNN=True)
validation_data = (X_valid_normalized[:, :, :9, :], y_valid)
dnn_normalized.train(X_train_normalized[:, :, :9, :], y_train, validation_data)
# Out:
# Training model...
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 100, 1, 1), filter_dilation=(1, 1)}(GpuFromHost.0, convolution2d_3_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd16574a7d0>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd16574a7d0>()]')
#
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 100, 1, 1), filter_dilation=(1, 1)}(GpuFromHost.0, convolution2d_3_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd16573fe90>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd16573fe90>()]')
#
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 100, 1, 1), filter_dilation=(1, 1)}(GpuFromHost.0, convolution2d_2_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd162ff4150>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd162ff4150>()]')
#
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 100, 1, 1), filter_dilation=(1, 1)}(GpuFromHost.0, convolution2d_2_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd162f8f650>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd162f8f650>()]')
#
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 1, 9, 1), filter_dilation=(1, 1)}(GpuFromHost.0, convolution2d_1_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd162f43c50>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd162f43c50>()]')
#
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 1, 9, 1), filter_dilation=(1, 1)}(GpuFromHost.0, convolution2d_1_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd162f59250>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd162f59250>()]')
#
# INFO (theano.gof.compilelock): Refreshing lock /users/mtaranov/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/lock_dir/lock
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 100, 1, 1), filter_dilation=(1, 1)}(GpuElemwise{mul,no_inplace}.0, convolution2d_3_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd162fb5310>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd162fb5310>()]')
#
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 100, 1, 1), filter_dilation=(1, 1)}(GpuElemwise{mul,no_inplace}.0, convolution2d_3_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd16574ad10>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd16574ad10>()]')
#
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 100, 1, 1), filter_dilation=(1, 1)}(GpuElemwise{mul,no_inplace}.0, convolution2d_2_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd165706950>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd165706950>()]')
#
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 100, 1, 1), filter_dilation=(1, 1)}(GpuElemwise{mul,no_inplace}.0, convolution2d_2_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd162f02a90>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd162f02a90>()]')
#
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 1, 9, 1), filter_dilation=(1, 1)}(GpuFromHost.0, convolution2d_1_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd162f12650>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd162f12650>()]')
#
# ERROR (theano.gof.opt): Optimization failure due to: LocalOptGroup(local_conv_dnn,local_conv_gemm,local_abstractconv_cudnn,local_abstractconv3d_cudnn,local_abstractconv_gemm,local_abstractconv3d_gemm,local_abstractconv_gradweight_gemm,local_abstractconv3d_gradweight_gemm,local_abstractconv_gradinputs_gemm,local_abstractconv3d_gradinputs_gemm)
# ERROR (theano.gof.opt): node: AbstractConv2d{convdim=2, border_mode='half', subsample=(1, 1), filter_flip=True, imshp=(None, None, None, None), kshp=(100, 1, 9, 1), filter_dilation=(1, 1)}(GpuFromHost.0, convolution2d_1_W)
# ERROR (theano.gof.opt): TRACEBACK:
# ERROR (theano.gof.opt): Traceback (most recent call last):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1982, in process_node
#     replacements = lopt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/opt.py", line 1335, in transform
#     new_repl = opt.transform(node)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 3548, in local_abstractconv_cudnn
#     conv_mode=conv_mode)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 1186, in dnn_conv
#     return GpuDnnConv(algo=algo)(img, kerns, out, desc)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/dnn.py", line 359, in __init__
#     if version() < (5000, 5000):
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py", line 429, in dnn_version
#     profile=False)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function.py", line 326, in function
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.py", line 486, in pfunc
#     output_keys=output_keys)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1795, in orig_function
#     defaults)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.py", line 1661, in create
#     input_storage=input_storage_lists, storage_map=storage_map)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/link.py", line 699, in make_thunk
#     storage_map=storage_map)[:3]
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/vm.py", line 1047, in make_all
#     impl=impl))
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 935, in make_thunk
#     no_recycling)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/op.py", line 839, in make_c_thunk
#     output_storage=node_output_storage)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1190, in make_thunk
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1131, in __compile__
#     keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1586, in cthunk_factory
#     key=key, lnk=self, keep_lock=keep_lock)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 1159, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cc.py", line 1489, in compile_cmodule
#     preargs=preargs)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.py", line 417, in compile_str
#     return dlimport(lib_filename)
#   File "/users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/gof/cmodule.py", line 302, in dlimport
#     rval = __import__(module_name, {}, {}, [module_name])
# ImportError: ('The following error happened while compiling the node', <theano.sandbox.cuda.DnnVersion object at 0x7fd162f17ad0>(), '\n', 'libcudnn.so.5: cannot open shared object file: No such file or directory', '[<theano.sandbox.cuda.DnnVersion object at 0x7fd162f17ad0>()]')

# %%
print(dnn_normalized.test(X_test_normalized[:, :, :9, :], y_test))
print(dnn_normalized.test(X_train_normalized[:, :, :9, :], y_train))
print(dnn_normalized.test(X_valid_normalized[:, :, :9, :], y_valid))

# %%
#save model and weights
dnn_normalized.save(contacts+'_dnn_Siamese_linear_genomic_features_'+'thres_'+thres, '/users/mtaranov/genome3D/')
