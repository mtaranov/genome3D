# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import copy
sys.path.append('/users/mtaranov/genome3D/')
from models_3d import Genome3D_DNN_FC
from utils import get_features, get_labels, subsample_data, normalize_features, makedirs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
contacts='pe'
thres='10'
path='/users/mtaranov/datasets_3d/by_chr_dist_matched_'+contacts+'/'
X_train = get_features(path+'d0_X_train_thres_10.npy')
y_train = get_labels(path+'d0_y_train_thres_10.npy')
X_valid = get_features(path+'d0_X_valid_thres_10.npy')
y_valid = get_labels(path+'d0_y_valid_thres_10.npy')
X_test = get_features(path+'d0_X_test_thres_10.npy')
y_test = get_labels(path+'d0_y_test_thres_10.npy')

# %%
X_train_normalized, X_valid_normalized, X_test_normalized = normalize_features(X_train, X_valid, X_test)

# %%
X_train_pairs = X_train_normalized.reshape(X_train_normalized.shape[0],X_train_normalized.shape[2]*X_train_normalized.shape[3])
X_valid_pairs = X_valid_normalized.reshape(X_valid_normalized.shape[0],X_valid_normalized.shape[2]*X_valid_normalized.shape[3])
X_test_pairs = X_test_normalized.reshape(X_test_normalized.shape[0],X_test_normalized.shape[2]*X_test_normalized.shape[3])

# %% [markdown]
# # without genomic location

# %%
dnn_normalized = Genome3D_DNN_FC(num_features=18, use_deep_CNN=True)
validation_data = (X_valid_pairs[:,:18], y_valid)
dnn_normalized.train(X_train_pairs[:,:18], y_train, validation_data)
# Out:
# Training model...
# Train on 6710 samples, validate on 1796 samples
# Epoch 1/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.4812Epoch 0: validation loss: 0.630
# Balanced Accuracy: 65.76%	auROC: 0.711	 auPRC: 0.687
# Positve Accuracy: 0.22%	 Negative Accuracy: 71.38%
# Recall at 5% | 10% | 25% | 50% FDR: 60.1% | 0.2% | 27.1% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.4793 - val_loss: 0.6301
# Epoch 2/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.3561Epoch 1: validation loss: 0.605
# Balanced Accuracy: 67.26%	auROC: 0.741	 auPRC: 0.716
# Positve Accuracy: 0.11%	 Negative Accuracy: 67.15%
# Recall at 5% | 10% | 25% | 50% FDR: 67.4% | 0.1% | 42.4% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.3550 - val_loss: 0.6050
# Epoch 3/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.2976Epoch 2: validation loss: 0.593
# Balanced Accuracy: 68.21%	auROC: 0.756	 auPRC: 0.732
# Positve Accuracy: 0.11%	 Negative Accuracy: 66.15%
# Recall at 5% | 10% | 25% | 50% FDR: 70.3% | 0.1% | 48.8% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.2964 - val_loss: 0.5930
# Epoch 4/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.2829Epoch 3: validation loss: 0.586
# Balanced Accuracy: 69.38%	auROC: 0.765	 auPRC: 0.744
# Positve Accuracy: 0.11%	 Negative Accuracy: 66.04%
# Recall at 5% | 10% | 25% | 50% FDR: 72.7% | 3.9% | 52.8% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.2806 - val_loss: 0.5860
# Epoch 5/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.2677Epoch 4: validation loss: 0.583
# Balanced Accuracy: 69.93%	auROC: 0.770	 auPRC: 0.750
# Positve Accuracy: 0.11%	 Negative Accuracy: 65.03%
# Recall at 5% | 10% | 25% | 50% FDR: 74.8% | 4.0% | 58.8% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.2685 - val_loss: 0.5827
# Epoch 6/100
# 6250/6710 [==========================>...] - ETA: 0s - loss: 1.2383Epoch 5: validation loss: 0.581
# Balanced Accuracy: 70.99%	auROC: 0.774	 auPRC: 0.755
# Positve Accuracy: 0.11%	 Negative Accuracy: 64.70%
# Recall at 5% | 10% | 25% | 50% FDR: 77.3% | 4.2% | 61.9% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 3s - loss: 1.2426 - val_loss: 0.5807
# Epoch 7/100
# 6250/6710 [==========================>...] - ETA: 0s - loss: 1.2190Epoch 6: validation loss: 0.578
# Balanced Accuracy: 71.38%	auROC: 0.776	 auPRC: 0.757
# Positve Accuracy: 0.11%	 Negative Accuracy: 66.15%
# Recall at 5% | 10% | 25% | 50% FDR: 76.6% | 5.1% | 63.1% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 3s - loss: 1.2240 - val_loss: 0.5783
# Epoch 8/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.2106Epoch 7: validation loss: 0.577
# Balanced Accuracy: 71.88%	auROC: 0.778	 auPRC: 0.760
# Positve Accuracy: 0.11%	 Negative Accuracy: 65.92%
# Recall at 5% | 10% | 25% | 50% FDR: 77.8% | 5.7% | 65.6% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 4s - loss: 1.2081 - val_loss: 0.5765
# Epoch 9/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.2074Epoch 8: validation loss: 0.574
# Balanced Accuracy: 71.77%	auROC: 0.780	 auPRC: 0.762
# Positve Accuracy: 0.11%	 Negative Accuracy: 66.59%
# Recall at 5% | 10% | 25% | 50% FDR: 76.9% | 6.7% | 66.3% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 9s - loss: 1.2044 - val_loss: 0.5744
# Epoch 10/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.2141Epoch 9: validation loss: 0.574
# Balanced Accuracy: 72.27%	auROC: 0.781	 auPRC: 0.765
# Positve Accuracy: 0.11%	 Negative Accuracy: 65.70%
# Recall at 5% | 10% | 25% | 50% FDR: 78.8% | 7.5% | 66.4% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 8s - loss: 1.2139 - val_loss: 0.5737
# Epoch 11/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1922Epoch 10: validation loss: 0.571
# Balanced Accuracy: 72.27%	auROC: 0.783	 auPRC: 0.767
# Positve Accuracy: 0.11%	 Negative Accuracy: 66.26%
# Recall at 5% | 10% | 25% | 50% FDR: 78.3% | 7.9% | 66.4% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 8s - loss: 1.1920 - val_loss: 0.5714
# Epoch 12/100
# 6250/6710 [==========================>...] - ETA: 0s - loss: 1.1927Epoch 11: validation loss: 0.570
# Balanced Accuracy: 72.27%	auROC: 0.784	 auPRC: 0.770
# Positve Accuracy: 0.45%	 Negative Accuracy: 66.48%
# Recall at 5% | 10% | 25% | 50% FDR: 78.1% | 8.5% | 66.7% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 9s - loss: 1.1849 - val_loss: 0.5699
# Epoch 13/100
# 6000/6710 [=========================>....] - ETA: 0s - loss: 1.1916Epoch 12: validation loss: 0.569
# Balanced Accuracy: 72.49%	auROC: 0.785	 auPRC: 0.771
# Positve Accuracy: 0.56%	 Negative Accuracy: 66.26%
# Recall at 5% | 10% | 25% | 50% FDR: 78.7% | 8.4% | 67.5% | 99.1%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 6s - loss: 1.1900 - val_loss: 0.5692
# Epoch 14/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1740Epoch 13: validation loss: 0.569
# Balanced Accuracy: 72.22%	auROC: 0.786	 auPRC: 0.773
# Positve Accuracy: 0.67%	 Negative Accuracy: 65.70%
# Recall at 5% | 10% | 25% | 50% FDR: 78.7% | 8.4% | 67.6% | 99.1%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 7s - loss: 1.1779 - val_loss: 0.5688
# Epoch 15/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1615Epoch 14: validation loss: 0.567
# Balanced Accuracy: 72.77%	auROC: 0.787	 auPRC: 0.775
# Positve Accuracy: 0.67%	 Negative Accuracy: 66.59%
# Recall at 5% | 10% | 25% | 50% FDR: 79.0% | 8.2% | 68.8% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 8s - loss: 1.1598 - val_loss: 0.5674
# Epoch 16/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1749Epoch 15: validation loss: 0.566
# Balanced Accuracy: 72.61%	auROC: 0.788	 auPRC: 0.777
# Positve Accuracy: 0.78%	 Negative Accuracy: 66.82%
# Recall at 5% | 10% | 25% | 50% FDR: 78.4% | 10.9% | 68.2% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 9s - loss: 1.1765 - val_loss: 0.5658
# Epoch 17/100
# 6250/6710 [==========================>...] - ETA: 0s - loss: 1.1622Epoch 16: validation loss: 0.565
# Balanced Accuracy: 72.66%	auROC: 0.789	 auPRC: 0.779
# Positve Accuracy: 0.89%	 Negative Accuracy: 65.92%
# Recall at 5% | 10% | 25% | 50% FDR: 79.4% | 12.5% | 67.9% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 8s - loss: 1.1731 - val_loss: 0.5654
# Epoch 18/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1720Epoch 17: validation loss: 0.564
# Balanced Accuracy: 72.49%	auROC: 0.789	 auPRC: 0.780
# Positve Accuracy: 1.00%	 Negative Accuracy: 66.48%
# Recall at 5% | 10% | 25% | 50% FDR: 78.5% | 12.9% | 68.2% | 99.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 8s - loss: 1.1746 - val_loss: 0.5645
# Epoch 19/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1592Epoch 18: validation loss: 0.564
# Balanced Accuracy: 72.72%	auROC: 0.790	 auPRC: 0.781
# Positve Accuracy: 1.11%	 Negative Accuracy: 65.70%
# Recall at 5% | 10% | 25% | 50% FDR: 79.7% | 14.5% | 68.6% | 99.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 5s - loss: 1.1600 - val_loss: 0.5639
# Epoch 20/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1516Epoch 19: validation loss: 0.562
# Balanced Accuracy: 72.83%	auROC: 0.791	 auPRC: 0.782
# Positve Accuracy: 1.00%	 Negative Accuracy: 66.70%
# Recall at 5% | 10% | 25% | 50% FDR: 79.0% | 14.5% | 68.5% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.1527 - val_loss: 0.5623
# Epoch 21/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1526Epoch 20: validation loss: 0.561
# Balanced Accuracy: 73.05%	auROC: 0.791	 auPRC: 0.783
# Positve Accuracy: 1.00%	 Negative Accuracy: 67.71%
# Recall at 5% | 10% | 25% | 50% FDR: 78.4% | 15.3% | 68.3% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1528 - val_loss: 0.5606
# Epoch 22/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1528Epoch 21: validation loss: 0.560
# Balanced Accuracy: 72.88%	auROC: 0.792	 auPRC: 0.784
# Positve Accuracy: 1.11%	 Negative Accuracy: 66.59%
# Recall at 5% | 10% | 25% | 50% FDR: 79.2% | 15.9% | 69.0% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1511 - val_loss: 0.5604
# Epoch 23/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1571Epoch 22: validation loss: 0.560
# Balanced Accuracy: 73.11%	auROC: 0.793	 auPRC: 0.785
# Positve Accuracy: 1.00%	 Negative Accuracy: 67.04%
# Recall at 5% | 10% | 25% | 50% FDR: 79.2% | 16.4% | 69.2% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1533 - val_loss: 0.5599
# Epoch 24/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1505Epoch 23: validation loss: 0.558
# Balanced Accuracy: 73.05%	auROC: 0.793	 auPRC: 0.786
# Positve Accuracy: 0.89%	 Negative Accuracy: 67.82%
# Recall at 5% | 10% | 25% | 50% FDR: 78.3% | 18.4% | 69.2% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1507 - val_loss: 0.5582
# Epoch 25/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1352Epoch 24: validation loss: 0.558
# Balanced Accuracy: 73.11%	auROC: 0.794	 auPRC: 0.787
# Positve Accuracy: 0.89%	 Negative Accuracy: 67.48%
# Recall at 5% | 10% | 25% | 50% FDR: 78.7% | 18.4% | 69.2% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1366 - val_loss: 0.5583
# Epoch 26/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1313Epoch 25: validation loss: 0.557
# Balanced Accuracy: 73.33%	auROC: 0.794	 auPRC: 0.787
# Positve Accuracy: 0.56%	 Negative Accuracy: 68.26%
# Recall at 5% | 10% | 25% | 50% FDR: 78.4% | 18.5% | 69.3% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1333 - val_loss: 0.5567
# Epoch 27/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1407Epoch 26: validation loss: 0.557
# Balanced Accuracy: 73.44%	auROC: 0.795	 auPRC: 0.788
# Positve Accuracy: 0.56%	 Negative Accuracy: 67.48%
# Recall at 5% | 10% | 25% | 50% FDR: 79.4% | 19.7% | 70.3% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1413 - val_loss: 0.5571
# Epoch 28/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1440Epoch 27: validation loss: 0.556
# Balanced Accuracy: 73.22%	auROC: 0.795	 auPRC: 0.788
# Positve Accuracy: 0.45%	 Negative Accuracy: 67.71%
# Recall at 5% | 10% | 25% | 50% FDR: 78.7% | 19.6% | 70.3% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1423 - val_loss: 0.5562
# Epoch 29/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1366Epoch 28: validation loss: 0.556
# Balanced Accuracy: 73.55%	auROC: 0.796	 auPRC: 0.789
# Positve Accuracy: 0.45%	 Negative Accuracy: 67.59%
# Recall at 5% | 10% | 25% | 50% FDR: 79.5% | 17.4% | 70.2% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.1390 - val_loss: 0.5557
# Epoch 30/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1231Epoch 29: validation loss: 0.555
# Balanced Accuracy: 73.33%	auROC: 0.796	 auPRC: 0.789
# Positve Accuracy: 0.45%	 Negative Accuracy: 68.26%
# Recall at 5% | 10% | 25% | 50% FDR: 78.4% | 17.3% | 70.2% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1227 - val_loss: 0.5549
# Epoch 31/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1335Epoch 30: validation loss: 0.554
# Balanced Accuracy: 73.55%	auROC: 0.797	 auPRC: 0.790
# Positve Accuracy: 0.56%	 Negative Accuracy: 68.49%
# Recall at 5% | 10% | 25% | 50% FDR: 78.6% | 18.3% | 70.0% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1331 - val_loss: 0.5543
# Epoch 32/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1286Epoch 31: validation loss: 0.554
# Balanced Accuracy: 73.55%	auROC: 0.797	 auPRC: 0.791
# Positve Accuracy: 0.45%	 Negative Accuracy: 68.60%
# Recall at 5% | 10% | 25% | 50% FDR: 78.5% | 20.5% | 70.2% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1267 - val_loss: 0.5538
# Epoch 33/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1198Epoch 32: validation loss: 0.554
# Balanced Accuracy: 73.83%	auROC: 0.798	 auPRC: 0.792
# Positve Accuracy: 0.45%	 Negative Accuracy: 68.15%
# Recall at 5% | 10% | 25% | 50% FDR: 79.5% | 19.8% | 70.5% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1193 - val_loss: 0.5536
# Epoch 34/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1156Epoch 33: validation loss: 0.553
# Balanced Accuracy: 74.11%	auROC: 0.798	 auPRC: 0.793
# Positve Accuracy: 0.45%	 Negative Accuracy: 68.04%
# Recall at 5% | 10% | 25% | 50% FDR: 80.2% | 20.4% | 70.6% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1131 - val_loss: 0.5529
# Epoch 35/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1163Epoch 34: validation loss: 0.552
# Balanced Accuracy: 73.94%	auROC: 0.798	 auPRC: 0.793
# Positve Accuracy: 0.33%	 Negative Accuracy: 68.60%
# Recall at 5% | 10% | 25% | 50% FDR: 79.3% | 20.6% | 70.5% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1135 - val_loss: 0.5523
# Epoch 36/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1132Epoch 35: validation loss: 0.552
# Balanced Accuracy: 73.83%	auROC: 0.798	 auPRC: 0.793
# Positve Accuracy: 0.33%	 Negative Accuracy: 68.93%
# Recall at 5% | 10% | 25% | 50% FDR: 78.7% | 20.6% | 70.2% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.1145 - val_loss: 0.5520
# Epoch 37/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1240Epoch 36: validation loss: 0.551
# Balanced Accuracy: 73.55%	auROC: 0.799	 auPRC: 0.794
# Positve Accuracy: 0.33%	 Negative Accuracy: 69.49%
# Recall at 5% | 10% | 25% | 50% FDR: 77.6% | 20.8% | 70.4% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1237 - val_loss: 0.5507
# Epoch 38/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1131Epoch 37: validation loss: 0.551
# Balanced Accuracy: 74.00%	auROC: 0.799	 auPRC: 0.794
# Positve Accuracy: 0.33%	 Negative Accuracy: 69.71%
# Recall at 5% | 10% | 25% | 50% FDR: 78.3% | 21.6% | 70.5% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1129 - val_loss: 0.5507
# Epoch 39/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0975Epoch 38: validation loss: 0.550
# Balanced Accuracy: 74.33%	auROC: 0.800	 auPRC: 0.794
# Positve Accuracy: 0.22%	 Negative Accuracy: 69.49%
# Recall at 5% | 10% | 25% | 50% FDR: 79.2% | 21.5% | 70.9% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.0977 - val_loss: 0.5503
# Epoch 40/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1188Epoch 39: validation loss: 0.549
# Balanced Accuracy: 74.16%	auROC: 0.800	 auPRC: 0.795
# Positve Accuracy: 0.45%	 Negative Accuracy: 69.60%
# Recall at 5% | 10% | 25% | 50% FDR: 78.7% | 20.3% | 70.4% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1199 - val_loss: 0.5493
# Epoch 41/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1135Epoch 40: validation loss: 0.549
# Balanced Accuracy: 74.16%	auROC: 0.801	 auPRC: 0.795
# Positve Accuracy: 0.22%	 Negative Accuracy: 69.04%
# Recall at 5% | 10% | 25% | 50% FDR: 79.3% | 20.4% | 71.4% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.1125 - val_loss: 0.5494
# Epoch 42/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1146Epoch 41: validation loss: 0.549
# Balanced Accuracy: 73.94%	auROC: 0.801	 auPRC: 0.795
# Positve Accuracy: 0.22%	 Negative Accuracy: 69.15%
# Recall at 5% | 10% | 25% | 50% FDR: 78.7% | 20.5% | 71.4% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1149 - val_loss: 0.5493
# Epoch 43/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0975Epoch 42: validation loss: 0.549
# Balanced Accuracy: 74.05%	auROC: 0.801	 auPRC: 0.796
# Positve Accuracy: 0.33%	 Negative Accuracy: 68.93%
# Recall at 5% | 10% | 25% | 50% FDR: 79.2% | 20.3% | 71.4% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0943 - val_loss: 0.5489
# Epoch 44/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0969Epoch 43: validation loss: 0.548
# Balanced Accuracy: 73.89%	auROC: 0.802	 auPRC: 0.796
# Positve Accuracy: 0.45%	 Negative Accuracy: 69.93%
# Recall at 5% | 10% | 25% | 50% FDR: 77.8% | 24.8% | 71.6% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0987 - val_loss: 0.5478
# Epoch 45/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1143Epoch 44: validation loss: 0.548
# Balanced Accuracy: 73.89%	auROC: 0.802	 auPRC: 0.796
# Positve Accuracy: 0.22%	 Negative Accuracy: 69.71%
# Recall at 5% | 10% | 25% | 50% FDR: 78.1% | 25.4% | 71.4% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1140 - val_loss: 0.5479
# Epoch 46/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0975Epoch 45: validation loss: 0.548
# Balanced Accuracy: 74.22%	auROC: 0.802	 auPRC: 0.796
# Positve Accuracy: 0.11%	 Negative Accuracy: 69.27%
# Recall at 5% | 10% | 25% | 50% FDR: 79.2% | 25.4% | 71.7% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0938 - val_loss: 0.5484
# Epoch 47/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0973Epoch 46: validation loss: 0.548
# Balanced Accuracy: 73.94%	auROC: 0.802	 auPRC: 0.797
# Positve Accuracy: 0.22%	 Negative Accuracy: 69.49%
# Recall at 5% | 10% | 25% | 50% FDR: 78.4% | 25.6% | 71.6% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.0997 - val_loss: 0.5479
# Epoch 48/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0962Epoch 47: validation loss: 0.547
# Balanced Accuracy: 73.94%	auROC: 0.802	 auPRC: 0.797
# Positve Accuracy: 0.22%	 Negative Accuracy: 69.82%
# Recall at 5% | 10% | 25% | 50% FDR: 78.1% | 25.5% | 71.8% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0937 - val_loss: 0.5472
# Epoch 49/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0989Epoch 48: validation loss: 0.547
# Balanced Accuracy: 74.05%	auROC: 0.803	 auPRC: 0.797
# Positve Accuracy: 0.22%	 Negative Accuracy: 69.93%
# Recall at 5% | 10% | 25% | 50% FDR: 78.2% | 25.3% | 72.0% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1024 - val_loss: 0.5470
# Epoch 50/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0879Epoch 49: validation loss: 0.546
# Balanced Accuracy: 73.94%	auROC: 0.803	 auPRC: 0.797
# Positve Accuracy: 0.22%	 Negative Accuracy: 70.04%
# Recall at 5% | 10% | 25% | 50% FDR: 77.8% | 25.2% | 72.0% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0874 - val_loss: 0.5459
# Epoch 51/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0863Epoch 50: validation loss: 0.547
# Balanced Accuracy: 73.89%	auROC: 0.803	 auPRC: 0.798
# Positve Accuracy: 0.22%	 Negative Accuracy: 69.60%
# Recall at 5% | 10% | 25% | 50% FDR: 78.2% | 25.4% | 72.3% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0891 - val_loss: 0.5465
# Epoch 52/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0829Epoch 51: validation loss: 0.546
# Balanced Accuracy: 74.39%	auROC: 0.804	 auPRC: 0.798
# Positve Accuracy: 0.22%	 Negative Accuracy: 70.38%
# Recall at 5% | 10% | 25% | 50% FDR: 78.4% | 25.3% | 71.9% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0849 - val_loss: 0.5456
# Epoch 53/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0918Epoch 52: validation loss: 0.546
# Balanced Accuracy: 74.50%	auROC: 0.804	 auPRC: 0.798
# Positve Accuracy: 0.22%	 Negative Accuracy: 70.27%
# Recall at 5% | 10% | 25% | 50% FDR: 78.7% | 25.2% | 71.7% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0896 - val_loss: 0.5461
# Epoch 54/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0810Epoch 53: validation loss: 0.544
# Balanced Accuracy: 74.67%	auROC: 0.804	 auPRC: 0.798
# Positve Accuracy: 0.22%	 Negative Accuracy: 70.94%
# Recall at 5% | 10% | 25% | 50% FDR: 78.4% | 25.1% | 71.9% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0805 - val_loss: 0.5445
# Epoch 55/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0882Epoch 54: validation loss: 0.546
# Balanced Accuracy: 74.39%	auROC: 0.805	 auPRC: 0.800
# Positve Accuracy: 0.33%	 Negative Accuracy: 69.71%
# Recall at 5% | 10% | 25% | 50% FDR: 79.1% | 25.1% | 72.0% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0864 - val_loss: 0.5455
# Epoch 56/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0757Epoch 55: validation loss: 0.545
# Balanced Accuracy: 74.50%	auROC: 0.805	 auPRC: 0.800
# Positve Accuracy: 0.33%	 Negative Accuracy: 70.04%
# Recall at 5% | 10% | 25% | 50% FDR: 79.0% | 25.1% | 71.9% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0798 - val_loss: 0.5450
# Epoch 57/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0940Epoch 56: validation loss: 0.544
# Balanced Accuracy: 74.39%	auROC: 0.805	 auPRC: 0.799
# Positve Accuracy: 0.22%	 Negative Accuracy: 70.49%
# Recall at 5% | 10% | 25% | 50% FDR: 78.3% | 25.1% | 73.2% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0908 - val_loss: 0.5438
# Epoch 58/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0803Epoch 57: validation loss: 0.544
# Balanced Accuracy: 74.55%	auROC: 0.805	 auPRC: 0.799
# Positve Accuracy: 2.67%	 Negative Accuracy: 70.38%
# Recall at 5% | 10% | 25% | 50% FDR: 78.7% | 26.3% | 72.9% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.0845 - val_loss: 0.5441
# Epoch 59/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0769Epoch 58: validation loss: 0.545
# Balanced Accuracy: 74.44%	auROC: 0.805	 auPRC: 0.799
# Positve Accuracy: 0.22%	 Negative Accuracy: 70.16%
# Recall at 5% | 10% | 25% | 50% FDR: 78.7% | 25.8% | 72.6% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0814 - val_loss: 0.5446
# Epoch 60/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0841Epoch 59: validation loss: 0.544
# Balanced Accuracy: 74.50%	auROC: 0.805	 auPRC: 0.799
# Positve Accuracy: 0.11%	 Negative Accuracy: 70.16%
# Recall at 5% | 10% | 25% | 50% FDR: 78.8% | 26.2% | 73.3% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.0837 - val_loss: 0.5442
# Epoch 61/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0846Epoch 60: validation loss: 0.544
# Balanced Accuracy: 74.39%	auROC: 0.806	 auPRC: 0.799
# Positve Accuracy: 0.22%	 Negative Accuracy: 70.82%
# Recall at 5% | 10% | 25% | 50% FDR: 78.0% | 26.3% | 73.8% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0816 - val_loss: 0.5435
# Epoch 62/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0767Epoch 61: validation loss: 0.543
# Balanced Accuracy: 74.50%	auROC: 0.806	 auPRC: 0.800
# Positve Accuracy: 0.22%	 Negative Accuracy: 71.16%
# Recall at 5% | 10% | 25% | 50% FDR: 77.8% | 26.5% | 73.3% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0783 - val_loss: 0.5429
# Epoch 63/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0736Epoch 62: validation loss: 0.544
# Balanced Accuracy: 74.44%	auROC: 0.806	 auPRC: 0.800
# Positve Accuracy: 0.22%	 Negative Accuracy: 70.38%
# Recall at 5% | 10% | 25% | 50% FDR: 78.5% | 26.9% | 74.2% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0727 - val_loss: 0.5440
# Epoch 64/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0742Epoch 63: validation loss: 0.543
# Balanced Accuracy: 74.50%	auROC: 0.806	 auPRC: 0.799
# Positve Accuracy: 0.22%	 Negative Accuracy: 70.60%
# Recall at 5% | 10% | 25% | 50% FDR: 78.4% | 26.8% | 74.1% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0745 - val_loss: 0.5434
# Epoch 65/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0817Epoch 64: validation loss: 0.543
# Balanced Accuracy: 74.67%	auROC: 0.807	 auPRC: 0.801
# Positve Accuracy: 0.33%	 Negative Accuracy: 70.71%
# Recall at 5% | 10% | 25% | 50% FDR: 78.6% | 26.7% | 73.7% | 99.7%	Num Positives: 898	 Num Negatives: 898

# %%
print(dnn_normalized.test(X_test_pairs[:,:18], y_test))
print(dnn_normalized.test(X_train_pairs[:,:18], y_train))
print(dnn_normalized.test(X_valid_pairs[:,:18], y_valid))

# %% [markdown]
# # DeepLift

# %%
makedirs('/users/mtaranov/genome3D/weights')
makedirs('/users/mtaranov/genome3D/models')
makedirs('/users/mtaranov/deeplift_scores')

# %%
#save model and weights
dnn_normalized.save(contacts+'_dnn_FC_linear_genomic_features_'+'thres_'+thres, '/users/mtaranov/genome3D/')

# %%
weights='/users/mtaranov/genome3D/weights/'+contacts+'_dnn_FC_linear_genomic_features_'+'thres_'+thres+'.weights.h5'
json_model='/users/mtaranov/genome3D/models/'+contacts+'_dnn_FC_linear_genomic_features_'+'thres_'+thres+'.arch.json'

# %%
scores = dnn_normalized.deeplift(X_valid_pairs[:,:18][np.where(y_valid ==1)[0]], weights, json_model, batch_size=128)
# Out:
# True
# nonlinear_mxts_mode is set to: RevealCancel
# INFO (theano.gof.compilelock): Refreshing lock /users/mtaranov/.theano/compiledir_Linux-4.4--generic-x86_64-with-debian-stretch-sid-x86_64-2.7.12-64/lock_dir/lock

# %%
np.save('/users/mtaranov/genome3D/deeplift_scores/'+contacts+'_scores_dnn_FC_linear_genomic_features.npy', scores)

# %%
scores.shape
# Out:
# (898, 18)

# %%
features = ['ATAC', 'CTCF', 'POL3', 'TP63', 'H3K27ac', 'H3K27me3', 'H3K4me1', 'H3K4me3', 'H3K9ac']
plt.plot(np.mean(scores, axis=0)[0:18:2])
x = [float(j) for j in range(np.shape(scores)[1]/2)]
plt.xticks(x, features, rotation='vertical')
plt.title('Promoter')

# %%
features = ['ATAC', 'CTCF', 'POL3', 'TP63', 'H3K27ac', 'H3K27me3', 'H3K4me1', 'H3K4me3', 'H3K9ac']
plt.plot(np.mean(scores, axis=0)[1:19:2])
x = [float(j) for j in range(np.shape(scores)[1]/2)]
plt.xticks(x, features, rotation='vertical')
plt.title('Enhancer')

# %% [markdown]
# # with genomic locations

# %%
dnn_normalized = Genome3D_DNN_FC(num_features=20, use_deep_CNN=True)
validation_data = (X_valid_pairs, y_valid)
dnn_normalized.train(X_train_pairs, y_train, validation_data)
# Out:
# Training model...
# Train on 6710 samples, validate on 1796 samples
# Epoch 1/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 2.0291Epoch 0: validation loss: 0.837
# Balanced Accuracy: 54.51%	auROC: 0.565	 auPRC: 0.598
# Positve Accuracy: 1.78%	 Negative Accuracy: 13.36%
# Recall at 5% | 10% | 25% | 50% FDR: 95.7% | 2.7% | 13.4% | 98.8%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 2.0219 - val_loss: 0.8373
# Epoch 2/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.5584Epoch 1: validation loss: 0.694
# Balanced Accuracy: 60.08%	auROC: 0.639	 auPRC: 0.654
# Positve Accuracy: 2.67%	 Negative Accuracy: 36.53%
# Recall at 5% | 10% | 25% | 50% FDR: 83.6% | 4.1% | 16.0% | 98.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.5561 - val_loss: 0.6938
# Epoch 3/100
# 6000/6710 [=========================>....] - ETA: 0s - loss: 1.4039Epoch 2: validation loss: 0.636
# Balanced Accuracy: 66.43%	auROC: 0.718	 auPRC: 0.708
# Positve Accuracy: 2.56%	 Negative Accuracy: 52.90%
# Recall at 5% | 10% | 25% | 50% FDR: 80.0% | 5.6% | 21.8% | 98.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.3951 - val_loss: 0.6360
# Epoch 4/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.3176Epoch 3: validation loss: 0.603
# Balanced Accuracy: 69.65%	auROC: 0.760	 auPRC: 0.740
# Positve Accuracy: 2.45%	 Negative Accuracy: 59.13%
# Recall at 5% | 10% | 25% | 50% FDR: 80.2% | 4.7% | 53.8% | 99.4%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.3193 - val_loss: 0.6033
# Epoch 5/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.2677Epoch 4: validation loss: 0.584
# Balanced Accuracy: 71.71%	auROC: 0.779	 auPRC: 0.758
# Positve Accuracy: 3.01%	 Negative Accuracy: 62.81%
# Recall at 5% | 10% | 25% | 50% FDR: 80.6% | 4.8% | 67.7% | 99.3%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.2631 - val_loss: 0.5841
# Epoch 6/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.2422Epoch 5: validation loss: 0.569
# Balanced Accuracy: 72.66%	auROC: 0.792	 auPRC: 0.771
# Positve Accuracy: 3.01%	 Negative Accuracy: 64.48%
# Recall at 5% | 10% | 25% | 50% FDR: 80.8% | 5.1% | 71.0% | 99.3%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.2417 - val_loss: 0.5695
# Epoch 7/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.2241Epoch 6: validation loss: 0.559
# Balanced Accuracy: 73.55%	auROC: 0.800	 auPRC: 0.780
# Positve Accuracy: 3.12%	 Negative Accuracy: 65.92%
# Recall at 5% | 10% | 25% | 50% FDR: 81.2% | 6.3% | 73.1% | 99.6%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.2233 - val_loss: 0.5591
# Epoch 8/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.2003Epoch 7: validation loss: 0.551
# Balanced Accuracy: 74.16%	auROC: 0.807	 auPRC: 0.787
# Positve Accuracy: 3.67%	 Negative Accuracy: 67.26%
# Recall at 5% | 10% | 25% | 50% FDR: 81.1% | 6.2% | 73.9% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.2000 - val_loss: 0.5509
# Epoch 9/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1825Epoch 8: validation loss: 0.544
# Balanced Accuracy: 74.16%	auROC: 0.812	 auPRC: 0.793
# Positve Accuracy: 3.56%	 Negative Accuracy: 67.59%
# Recall at 5% | 10% | 25% | 50% FDR: 80.7% | 6.2% | 74.2% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1853 - val_loss: 0.5437
# Epoch 10/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1848Epoch 9: validation loss: 0.538
# Balanced Accuracy: 74.72%	auROC: 0.817	 auPRC: 0.799
# Positve Accuracy: 4.45%	 Negative Accuracy: 68.37%
# Recall at 5% | 10% | 25% | 50% FDR: 81.1% | 6.7% | 75.6% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1832 - val_loss: 0.5382
# Epoch 11/100
# 6000/6710 [=========================>....] - ETA: 0s - loss: 1.1523Epoch 10: validation loss: 0.534
# Balanced Accuracy: 75.00%	auROC: 0.820	 auPRC: 0.803
# Positve Accuracy: 4.68%	 Negative Accuracy: 67.82%
# Recall at 5% | 10% | 25% | 50% FDR: 82.2% | 16.8% | 76.3% | 99.7%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.1564 - val_loss: 0.5344
# Epoch 12/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1593Epoch 11: validation loss: 0.530
# Balanced Accuracy: 75.22%	auROC: 0.823	 auPRC: 0.806
# Positve Accuracy: 4.68%	 Negative Accuracy: 67.82%
# Recall at 5% | 10% | 25% | 50% FDR: 82.6% | 13.3% | 77.2% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1582 - val_loss: 0.5297
# Epoch 13/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1473Epoch 12: validation loss: 0.526
# Balanced Accuracy: 75.50%	auROC: 0.825	 auPRC: 0.809
# Positve Accuracy: 1.34%	 Negative Accuracy: 68.26%
# Recall at 5% | 10% | 25% | 50% FDR: 82.7% | 23.7% | 77.5% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1455 - val_loss: 0.5265
# Epoch 14/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1356Epoch 13: validation loss: 0.524
# Balanced Accuracy: 75.11%	auROC: 0.828	 auPRC: 0.812
# Positve Accuracy: 1.34%	 Negative Accuracy: 67.37%
# Recall at 5% | 10% | 25% | 50% FDR: 82.9% | 24.8% | 77.3% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1358 - val_loss: 0.5245
# Epoch 15/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1410Epoch 14: validation loss: 0.521
# Balanced Accuracy: 75.45%	auROC: 0.830	 auPRC: 0.814
# Positve Accuracy: 2.45%	 Negative Accuracy: 68.15%
# Recall at 5% | 10% | 25% | 50% FDR: 82.7% | 24.7% | 77.1% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.1404 - val_loss: 0.5215
# Epoch 16/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1386Epoch 15: validation loss: 0.519
# Balanced Accuracy: 75.45%	auROC: 0.832	 auPRC: 0.816
# Positve Accuracy: 2.34%	 Negative Accuracy: 68.37%
# Recall at 5% | 10% | 25% | 50% FDR: 82.5% | 25.7% | 77.6% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1389 - val_loss: 0.5187
# Epoch 17/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1210Epoch 16: validation loss: 0.515
# Balanced Accuracy: 75.67%	auROC: 0.834	 auPRC: 0.818
# Positve Accuracy: 2.12%	 Negative Accuracy: 68.93%
# Recall at 5% | 10% | 25% | 50% FDR: 82.4% | 26.4% | 78.1% | 100.0%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1212 - val_loss: 0.5152
# Epoch 18/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1311Epoch 17: validation loss: 0.514
# Balanced Accuracy: 75.72%	auROC: 0.836	 auPRC: 0.820
# Positve Accuracy: 1.78%	 Negative Accuracy: 68.37%
# Recall at 5% | 10% | 25% | 50% FDR: 83.1% | 26.3% | 78.7% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1315 - val_loss: 0.5141
# Epoch 19/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1037Epoch 18: validation loss: 0.513
# Balanced Accuracy: 75.45%	auROC: 0.837	 auPRC: 0.821
# Positve Accuracy: 1.89%	 Negative Accuracy: 68.15%
# Recall at 5% | 10% | 25% | 50% FDR: 82.7% | 26.2% | 79.2% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1087 - val_loss: 0.5125
# Epoch 20/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1000Epoch 19: validation loss: 0.511
# Balanced Accuracy: 75.78%	auROC: 0.838	 auPRC: 0.823
# Positve Accuracy: 1.89%	 Negative Accuracy: 68.60%
# Recall at 5% | 10% | 25% | 50% FDR: 83.0% | 26.5% | 79.1% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.0991 - val_loss: 0.5106
# Epoch 21/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1054Epoch 20: validation loss: 0.509
# Balanced Accuracy: 75.95%	auROC: 0.838	 auPRC: 0.823
# Positve Accuracy: 1.89%	 Negative Accuracy: 69.04%
# Recall at 5% | 10% | 25% | 50% FDR: 82.9% | 25.9% | 79.5% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1075 - val_loss: 0.5090
# Epoch 22/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0943Epoch 21: validation loss: 0.509
# Balanced Accuracy: 75.84%	auROC: 0.839	 auPRC: 0.825
# Positve Accuracy: 2.23%	 Negative Accuracy: 68.49%
# Recall at 5% | 10% | 25% | 50% FDR: 83.2% | 25.7% | 79.4% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0959 - val_loss: 0.5089
# Epoch 23/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.1018Epoch 22: validation loss: 0.508
# Balanced Accuracy: 75.84%	auROC: 0.840	 auPRC: 0.826
# Positve Accuracy: 2.12%	 Negative Accuracy: 68.37%
# Recall at 5% | 10% | 25% | 50% FDR: 83.3% | 26.4% | 79.2% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.1005 - val_loss: 0.5083
# Epoch 24/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0854Epoch 23: validation loss: 0.508
# Balanced Accuracy: 75.95%	auROC: 0.841	 auPRC: 0.827
# Positve Accuracy: 2.34%	 Negative Accuracy: 68.04%
# Recall at 5% | 10% | 25% | 50% FDR: 83.9% | 29.7% | 79.0% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0847 - val_loss: 0.5084
# Epoch 25/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0892Epoch 24: validation loss: 0.505
# Balanced Accuracy: 76.28%	auROC: 0.842	 auPRC: 0.828
# Positve Accuracy: 2.34%	 Negative Accuracy: 69.27%
# Recall at 5% | 10% | 25% | 50% FDR: 83.3% | 28.4% | 79.3% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0900 - val_loss: 0.5049
# Epoch 26/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0799Epoch 25: validation loss: 0.504
# Balanced Accuracy: 76.28%	auROC: 0.843	 auPRC: 0.829
# Positve Accuracy: 2.34%	 Negative Accuracy: 69.15%
# Recall at 5% | 10% | 25% | 50% FDR: 83.4% | 28.3% | 79.7% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.0799 - val_loss: 0.5040
# Epoch 27/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0729Epoch 26: validation loss: 0.503
# Balanced Accuracy: 76.28%	auROC: 0.842	 auPRC: 0.828
# Positve Accuracy: 2.12%	 Negative Accuracy: 69.27%
# Recall at 5% | 10% | 25% | 50% FDR: 83.3% | 26.8% | 79.5% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0724 - val_loss: 0.5032
# Epoch 28/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0620Epoch 27: validation loss: 0.502
# Balanced Accuracy: 76.39%	auROC: 0.844	 auPRC: 0.830
# Positve Accuracy: 2.34%	 Negative Accuracy: 69.27%
# Recall at 5% | 10% | 25% | 50% FDR: 83.5% | 25.9% | 79.5% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0620 - val_loss: 0.5024
# Epoch 29/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0753Epoch 28: validation loss: 0.503
# Balanced Accuracy: 76.11%	auROC: 0.844	 auPRC: 0.831
# Positve Accuracy: 2.34%	 Negative Accuracy: 68.60%
# Recall at 5% | 10% | 25% | 50% FDR: 83.6% | 27.6% | 79.5% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 11s - loss: 1.0749 - val_loss: 0.5025
# Epoch 30/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0782Epoch 29: validation loss: 0.501
# Balanced Accuracy: 76.06%	auROC: 0.845	 auPRC: 0.832
# Positve Accuracy: 1.34%	 Negative Accuracy: 68.71%
# Recall at 5% | 10% | 25% | 50% FDR: 83.4% | 30.4% | 79.4% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0739 - val_loss: 0.5011
# Epoch 31/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0704Epoch 30: validation loss: 0.500
# Balanced Accuracy: 76.28%	auROC: 0.846	 auPRC: 0.832
# Positve Accuracy: 1.34%	 Negative Accuracy: 69.27%
# Recall at 5% | 10% | 25% | 50% FDR: 83.3% | 30.5% | 79.5% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0674 - val_loss: 0.4996
# Epoch 32/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0607Epoch 31: validation loss: 0.499
# Balanced Accuracy: 76.28%	auROC: 0.846	 auPRC: 0.832
# Positve Accuracy: 2.23%	 Negative Accuracy: 69.27%
# Recall at 5% | 10% | 25% | 50% FDR: 83.3% | 27.8% | 79.6% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0633 - val_loss: 0.4991
# Epoch 33/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0684Epoch 32: validation loss: 0.500
# Balanced Accuracy: 76.56%	auROC: 0.846	 auPRC: 0.834
# Positve Accuracy: 2.45%	 Negative Accuracy: 69.38%
# Recall at 5% | 10% | 25% | 50% FDR: 83.7% | 32.9% | 79.6% | 99.9%	Num Positives: 898	 Num Negatives: 898
#
#
# 6710/6710 [==============================] - 12s - loss: 1.0666 - val_loss: 0.4998
# Epoch 34/100
# 6500/6710 [============================>.] - ETA: 0s - loss: 1.0684Epoch 33: validation loss: 0.497
# Balanced Accuracy: 76.61%	auROC: 0.847	 auPRC: 0.834
# Positve Accuracy: 2.56%	 Negative Accuracy: 70.27%
# Recall at 5% | 10% | 25% | 50% FDR: 83.0% | 28.0% | 79.7% | 99.9%	Num Positives: 898	 Num Negatives: 898
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-8f8f01715299> in <module>()
#       1 dnn_normalized = Genome3D_DNN_FC(num_features=20, use_deep_CNN=True)
#       2 validation_data = (X_valid_pairs, y_valid)
# ----> 3 dnn_normalized.train(X_train_pairs, y_train, validation_data)
#
# /users/mtaranov/genome3D/models_3d.pyc in train(self, X, y, validation_data)
#     125                           False: num_sequences / num_negatives}
#     126             if not multitask else None,
# --> 127             callbacks=self.callbacks, verbose=self.verbose >= 2)
#     128         self.train_losses = self.callbacks[-1].train_losses
#     129         self.valid_losses = self.callbacks[-1].valid_losses
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/models.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     669                               class_weight=class_weight,
#     670                               sample_weight=sample_weight,
# --> 671                               initial_epoch=initial_epoch)
#     672
#     673     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch)
#    1143                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1144                               callback_metrics=callback_metrics,
# -> 1145                               initial_epoch=initial_epoch)
#    1146
#    1147     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#     863                         for l, o in zip(out_labels, val_outs):
#     864                             epoch_logs['val_' + l] = o
# --> 865             callbacks.on_epoch_end(epoch, epoch_logs)
#     866             if callback_model.stop_training:
#     867                 break
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/callbacks.pyc in on_epoch_end(self, epoch, logs)
#      41     def on_epoch_end(self, epoch, logs={}):
#      42         for callback in self.callbacks:
# ---> 43             callback.on_epoch_end(epoch, logs)
#      44
#      45     def on_batch_begin(self, batch, logs={}):
#
# /users/mtaranov/genome3D/models_3d.pyc in on_epoch_end(self, epoch, logs)
#      82         def on_epoch_end(self, epoch, logs={}):
#      83             self.train_losses.append(self.sequence_DNN.model.evaluate(
# ---> 84                 self.X_train, self.y_train, verbose=False))
#      85             self.valid_losses.append(self.sequence_DNN.model.evaluate(
#      86                 self.X_valid, self.y_valid, verbose=False))
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/models.pyc in evaluate(self, x, y, batch_size, verbose, sample_weight, **kwargs)
#     705                                    batch_size=batch_size,
#     706                                    verbose=verbose,
# --> 707                                    sample_weight=sample_weight)
#     708
#     709     def predict(self, x, batch_size=32, verbose=0):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/engine/training.pyc in evaluate(self, x, y, batch_size, verbose, sample_weight)
#    1183         return self._test_loop(f, ins,
#    1184                                batch_size=batch_size,
# -> 1185                                verbose=verbose)
#    1186
#    1187     def predict(self, x, batch_size=32, verbose=0):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/engine/training.pyc in _test_loop(self, f, ins, batch_size, verbose)
#     942                 ins_batch = slice_X(ins, batch_ids)
#     943
# --> 944             batch_outs = f(ins_batch)
#     945             if isinstance(batch_outs, list):
#     946                 if batch_index == 0:
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     955     def __call__(self, inputs):
#     956         assert isinstance(inputs, (list, tuple))
# --> 957         return self.function(*inputs)
#     958
#     959
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     882         try:
#     883             outputs =\
# --> 884                 self.fn() if output_subset is None else\
#     885                 self.fn(output_subset=output_subset)
#     886         except Exception:
#
# KeyboardInterrupt:

# %%
print(dnn_normalized.test(X_test_pairs, y_test))
print(dnn_normalized.test(X_train_pairs, y_train))
print(dnn_normalized.test(X_valid_pairs, y_valid))
# Out:
# Balanced Accuracy: 71.36%	auROC: 0.779	 auPRC: 0.775
# Positve Accuracy: 0.81%	 Negative Accuracy: 69.43%
# Recall at 5% | 10% | 25% | 50% FDR: 73.3% | 16.0% | 67.2% | 100.0%	Num Positives: 494	 Num Negatives: 494
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-bd4c8acf2897> in <module>()
#       1 print(dnn_normalized.test(X_test_pairs, y_test))
# ----> 2 print(dnn_normalized.test(X_train_pairs, y_train))
#       3 print(dnn_normalized.test(X_valid_pairs, y_valid))
#
# /users/mtaranov/genome3D/models_3d.pyc in test(self, X, y)
#      51
#      52     def test(self, X, y):
# ---> 53         return ClassificationResult(y, self.predict(X))
#      54
#      55     def score(self, X, y, metric):
#
# /users/mtaranov/genome3D/models_3d.pyc in predict(self, X)
#     130
#     131     def predict(self, X):
# --> 132         return self.model.predict(X, batch_size=128, verbose=False)
#     133
#     134
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/models.pyc in predict(self, x, batch_size, verbose)
#     721         if self.model is None:
#     722             self.build()
# --> 723         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     724
#     725     def predict_on_batch(self, x):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/engine/training.pyc in predict(self, x, batch_size, verbose)
#    1219         f = self.predict_function
#    1220         return self._predict_loop(f, ins,
# -> 1221                                   batch_size=batch_size, verbose=verbose)
#    1222
#    1223     def train_on_batch(self, x, y,
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose)
#     897                 ins_batch = slice_X(ins, batch_ids)
#     898
# --> 899             batch_outs = f(ins_batch)
#     900             if not isinstance(batch_outs, list):
#     901                 batch_outs = [batch_outs]
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/Keras-1.2.0-py2.7.egg/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     955     def __call__(self, inputs):
#     956         assert isinstance(inputs, (list, tuple))
# --> 957         return self.function(*inputs)
#     958
#     959
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     882         try:
#     883             outputs =\
# --> 884                 self.fn() if output_subset is None else\
#     885                 self.fn(output_subset=output_subset)
#     886         except Exception:
#
# KeyboardInterrupt:
